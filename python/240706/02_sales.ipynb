# %%
import pandas as pd

# %% [markdown]
# ### Sales Records 샘플
# - csv 폴더 안에 있는 'Sales Records.csv' 파일을 로드
# - 데이터프레임의 정보를 확인
# - 특정 컬럼을 제거 ('Order ID', 'Total Revenue', 'Total Cost', 'Total Profit', 'Order Priority')
# - 컬럼의 이름을 변경 ['대륙', '국가', '상품종류', '채널', '주문일자', '발송일자', '판매개수', '단가', '원가']
# - 대륙, 국가를 기준으로 데이터를 오름차순 정렬
# - 기존의 인덱스는 제거하고 인덱스를 재지정
# - 새로운 파생변수 생성
#     - 총단가 -> 판매개수 * 단가
#     - 총원가 -> 판매개수 * 원가
#     - 총이윤 -> 총단가 - 총원가

# %%
# 외부의 파일을 로드 
# 상위 디렉토리 이동(../) -> csv 디렉토리 이동(csv/) -> Sales Records.csv 
sales = pd.read_csv('../csv/Sales Records.csv')

# %%
# 정보를 확인 
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  object
#  1   Country         10000 non-null  object
#  2   Item Type       10000 non-null  object
#  3   Sales Channel   10000 non-null  object
#  4   Order Priority  10000 non-null  object
#  5   Order Date      10000 non-null  object
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  object
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
sales.head(1)
# Out:
#                Region Country        Item Type Sales Channel Order Priority  \
# 0  Sub-Saharan Africa    Chad  Office Supplies        Online              L
#
#   Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0  1/27/2011  292494523  2/12/2011        4484      651.21     524.96
#
#    Total Revenue  Total Cost  Total Profit
# 0     2920025.64  2353920.64      566105.0

# %%
# 특정 컬럼을 제거 -> Order ID, Order Priority, Total Revenue, Total Cost, Total Profit
# drop()함수를 이용
sales.drop(
    [
        'Order ID', 
        'Order Priority',
        'Total Revenue', 
        'Total Cost', 
        'Total Profit'
    ],
    axis='columns', 
    inplace=True
)

# %%
cols = sales.columns

# %%
# 컬럼의 이름을 변경 
# case1 -> rename()함수를 이용
sales.rename(
    {
        cols[0] : '대륙', 
        cols[1] : '국가', 
        cols[2] : '상품종류', 
        cols[3] : '채널', 
        cols[4] : '주문일자', 
        cols[5] : '발송일자', 
        cols[6] : '판매개수', 
        cols[7] : '단가', 
        cols[8] : '원가'
    }, 
    axis=1
)
# Out:
#                                 대륙                                국가  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#                  상품종류       채널        주문일자       발송일자  판매개수      단가      원가
# 0     Office Supplies   Online   1/27/2011  2/12/2011  4484  651.21  524.96
# 1           Beverages   Online  12/28/2015  1/23/2016  1075   47.45   31.79
# 2          Vegetables  Offline   1/13/2011   2/1/2011  6515  154.06   90.93
# 3           Household   Online   9/11/2012  10/6/2012  7683  668.27  502.54
# 4           Beverages   Online  10/27/2015  12/5/2015  3491   47.45   31.79
# ...               ...      ...         ...        ...   ...     ...     ...
# 9995        Beverages   Online   7/15/2014  7/31/2014  8597   47.45   31.79
# 9996        Cosmetics   Online  10/27/2012  11/1/2012   562  437.20  263.33
# 9997       Vegetables  Offline   2/14/2013  3/20/2013  2524  154.06   90.93
# 9998             Meat   Online   2/19/2017  2/22/2017  8706  421.89  364.69
# 9999           Snacks  Offline   4/12/2016  4/16/2016   361  152.58   97.44
#
# [10000 rows x 9 columns]

# %%
# case2 -> sales 안에 있는 columns라는 변수에 데이터를 대입 (컬럼 전체를 변경할때 사용)
sales.columns = [
    '대륙', '국가', '상품종류', '채널', '주문일자', '발송일자', 
    '판매개수', '단가', '원가'
]

# %%
sales.head(1)
# Out:
#                    대륙    국가             상품종류      채널       주문일자       발송일자  \
# 0  Sub-Saharan Africa  Chad  Office Supplies  Online  1/27/2011  2/12/2011
#
#    판매개수      단가      원가
# 0  4484  651.21  524.96

# %%
# 대륙, 국가를 기준으로 데이터를 오름차순 정렬 
# sort_values()함수를 사용
sales.sort_values(
    ['대륙', '국가'], inplace=True
)

# %%
# 인덱스를 초기화하고 기존의 인덱스는 제거 
# reset_index()함수를 사용
sales.reset_index(drop=True, inplace=True)

# %%
# 3개의 파생 변수를 생성 
# 총단가, 총원가, 총이윤
sales['총단가'] = sales['단가'] * sales['판매개수']

# %%
# 총원가 컬럼은 for문을 이용하여 생성 
# 총원가 데이터를 대입할 빈 리스트를 생성 
data = []

# 만번(sales의 인덱스의 수) 반복 실행하는 반복문을 생성 
for i in range(0, len(sales), 1):
    # i가 의미하는것은? sales의 인덱스의 값 이거나 위치
    # print(i)
    # 인덱스가 i인 데이터에서 원가 데이터와 판매개수 데이터를 곱한 값을 data라는 리스트에 추가 
    res = sales.loc[i, '원가'] * sales.loc[i, '판매개수']
    data.append(res)

print(data)
# Out:
# [533831.4, 151941.41, 3091.6200000000003, 1143930.48, 4058465.7600000002, 1859900.54, 315143.01, 566109.74, 209984.0, 561856.4700000001, 67140.48, 2763914.4000000004, 28370.160000000003, 1039626.84, 4933.96, 5192904.32, 3610066.31, 7874.96, 358551.09, 532509.6, 2927731.32, 3226777.12, 843709.32, 1164658.95, 568312.5, 187192.32, 1156344.14, 175506.99000000002, 1121913.8, 1582086.64, 4627388.32, 46564.68, 225505.28000000003, 4698749.0, 153323.52000000002, 682611.51, 138462.24, 499708.37, 1545.8100000000002, 585589.2000000001, 543520.32, 452137.61, 344079.12000000005, 154822.44, 183950.82, 40108.32, 1009606.8599999999, 896545.44, 250141.38, 2732941.7600000002, 901278.5599999999, 4529393.0200000005, 58716.13, 1037845.92, 1676844.6199999999, 2566150.8499999996, 28647.36, 217510.58, 63719.36, 840907.2, 2051018.7200000002, 15782.579999999998, 1074132.92, 167372.80000000002, 4002228.56, 77880.32, 294067.2, 462710.55, 107933.91, 575112.72, 1526605.92, 12421.4, 294533.12000000005, 249016.32000000004, 1246983.24, 44855.44, 711800.04, 1319813.11, 279463.25999999995, 272454.24, 186224.64, 21617.2, 4512031.2, 2454498.9299999997, 104738.93999999999, 90550.56, 992155.92, 47678.8, 245874.72000000003, 207.6, 349547.52, 41710.82, 1389855.74, 579378.24, 685430.3400000001, 1898082.64, 462547.68, 852502.5599999999, 53429.32, 17812.480000000003, 815369.31, 580045.83, 193607.68000000002, 31624.4, 33474.560000000005, 3130134.27, 1060548.16, 2556923.52, 322792.32, 4385164.04, 1082302.38, 3592658.46, 1207488.59, 109025.07, 590987.04, 275894.46, 197988.12, 258301.86000000002, 1061953.48, 61990.5, 346897.95, 16275.84, 637842.8099999999, 336896.00000000006, 1383995.1600000001, 44939.310000000005, 8314.880000000001, 10518.4, 502970.1, 1517570.7899999998, 658245.1799999999, 4494707.5200000005, 99894.83, 2900744.26, 926362.08, 2549887.96, 114544.64000000001, 860290.0599999999, 648672.29, 744650.82, 3942974.56, 2182258.72, 405456.87000000005, 1072493.38, 1830010.56, 1325076.5599999998, 710045.28, 651741.75, 75049.04999999999, 820916.04, 5023389.84, 71898.42, 1107969.0, 4919364.0600000005, 150138.56, 1831108.49, 222260.63999999998, 57649.62, 3023644.79, 333276.16000000003, 912360.6599999999, 239728.38999999998, 585198.67, 114571.8, 226758.07, 3598600.8000000003, 472627.8, 433189.89, 88718.24, 2350770.8800000004, 99348.48000000001, 299670.96, 1867282.7200000002, 14649.64, 232829.96, 3450696.78, 385764.95999999996, 210237.44000000003, 3443767.67, 1148118.8, 486111.78, 27668.480000000003, 269862.54, 2983579.98, 1609736.2899999998, 404680.47000000003, 164131.77, 162211.84000000003, 384693.12, 506025.45, 2998656.18, 404057.10000000003, 4089438.4000000004, 745756.48, 967.6800000000001, 1878882.88, 3553979.2, 21504.000000000004, 147036.96, 561765.54, 239662.08000000002, 231203.84000000003, 2058977.2699999998, 571426.1, 241131.52000000002, 22822.16, 14280.84, 952056.2399999999, 505095.65, 3194319.71, 855822.5, 913228.44, 1586036.81, 947701.44, 784505.82, 215685.96000000002, 273711.89999999997, 11953.039999999999, 18433.1, 123504.64000000001, 195624.84, 115266.78, 834760.08, 3714616.9600000004, 2111170.54, 104455.68, 212614.27, 210302.37, 944140.82, 99216.59, 777013.08, 12324.52, 530868.6, 27984.48, 2649473.12, 148475.4, 226645.44, 944828.0399999999, 34142.46, 88008.51000000001, 2151142.77, 184719.36000000002, 1999606.6600000001, 477728.10000000003, 1061418.3599999999, 1461562.5599999998, 726636.36, 66459.68, 532834.4, 698742.24, 86691.33, 1994198.0899999999, 451943.25, 220304.69999999998, 266273.04, 798183.54, 260569.75, 378912.91, 668129.22, 367941.36, 4612814.66, 1621322.8099999998, 164539.55, 537917.75, 2440542.44, 1122030.91, 5240675.680000001, 37416.96, 398818.98000000004, 167946.24000000002, 5504.17, 916664.9999999999, 183682.62, 2571779.04, 2045546.21, 390682.98000000004, 840812.69, 172641.28000000003, 330367.31, 1393809.0599999998, 5032266.5600000005, 197034.41999999998, 26664.960000000003, 2594063.83, 476028.0, 377359.5, 2682558.52, 96395.67, 298253.7799999999 ...

# %%
sales['총원가'] = data

# %%
sales.head(2)
# Out:
#      대륙          국가           상품종류       채널        주문일자       발송일자  판매개수  \
# 0  Asia  Bangladesh  Personal Care   Online  12/11/2016  1/13/2017  9420
# 1  Asia  Bangladesh      Cosmetics  Offline   7/29/2010  9/11/2010   577
#
#        단가      원가       총단가        총원가
# 0   81.73   56.67  769896.6  533831.40
# 1  437.20  263.33  252264.4  151941.41

# %%
# 총이윤 컬럼의 데이터를 생성 
# 컬럼에 들어갈 데이터를 위해 빈 리스트 하나 생성 
data2 = []

# 시작값을 지정 
i = 0

# 무한반복문을 생성 
while True:
    try:
        res2 = sales.loc[i, '총단가'] - sales.loc[i, '총원가']
        data2.append(res2)
        # 시작값을 1 증가시킨다. 
        i += 1
    except:
        # 위의 코드가 에러가 발생한다면 -> 반복문을 종료
        break

# %%
sales['총이윤'] = data2

# %%
sales.head(3)
# Out:
#      대륙          국가           상품종류       채널        주문일자       발송일자  판매개수  \
# 0  Asia  Bangladesh  Personal Care   Online  12/11/2016  1/13/2017  9420
# 1  Asia  Bangladesh      Cosmetics  Offline   7/29/2010  9/11/2010   577
# 2  Asia  Bangladesh     Vegetables  Offline   4/28/2014   5/5/2014    34
#
#        단가      원가        총단가        총원가        총이윤
# 0   81.73   56.67  769896.60  533831.40  236065.20
# 1  437.20  263.33  252264.40  151941.41  100322.99
# 2  154.06   90.93    5238.04    3091.62    2146.42

# %% [markdown]
# ### 데이터프레임을 그룹화
# - groupby( [그룹화할 컬럼의 명] )
#     - 출력은 groupby data라는 형태로 텍스트 한줄이 출력
# - 그룹화 연산
#     - 그룹화된 데이터들을 연산하여 새로운 데이터프레임으로 생성
# - 그룹화 선택
#     - 그룹하된 데이터들 중에 특정 데이터프레임을 출력

# %%
sales[ ['단가'] ]
# Out:
#           단가
# 0      81.73
# 1     437.20
# 2     154.06
# 3     205.70
# 4     651.21
# ...      ...
# 9995  109.28
# 9996  255.28
# 9997  109.28
# 9998    9.33
# 9999  205.70
#
# [10000 rows x 1 columns]

# %%
group_data = sales[ ['국가','총이윤'] ].groupby(['국가']).sum()

# %%
group_data.head(1)
# Out:
#                      총이윤
# 국가
# Afghanistan  22977020.06

# %%
# gorup_data에서 sum을 기준으로 내림차순 정렬 
group_data.sort_values(['총이윤'], ascending=False)
# Out:
#                     총이윤
# 국가
# Kiribati    32454798.26
# Qatar       30861356.79
# Grenada     30302769.90
# Taiwan      30044779.98
# Malawi      29329125.05
# ...                 ...
# Cape Verde  14383303.52
# Italy       14199991.25
# Malta       14163744.55
# Mali        13800334.90
# Tajikistan  13662027.26
#
# [185 rows x 1 columns]

# %%
sales.head(2)
# Out:
#      대륙          국가           상품종류       채널        주문일자       발송일자  판매개수  \
# 0  Asia  Bangladesh  Personal Care   Online  12/11/2016  1/13/2017  9420
# 1  Asia  Bangladesh      Cosmetics  Offline   7/29/2010  9/11/2010   577
#
#        단가      원가       총단가        총원가        총이윤
# 0   81.73   56.67  769896.6  533831.40  236065.20
# 1  437.20  263.33  252264.4  151941.41  100322.99

# %%
# 그룹화 연산을 2개 이상 사용시 
group_data2 = sales[['국가', '총이윤']].groupby(['국가']).agg(['sum', 'mean'])

# %%
# group_data2에서 국가가 South Korea인 총 이윤의 합계값을 출력 
group_data2.loc['South Korea', ('총이윤', 'sum')]
# Out:
# 23893933.75

# %%
group_data2['총이윤']['sum']['South Korea']
# Out:
# 23893933.75

# %%
group_data2.iloc[[20]]
# Out:
#                총이윤
#                sum           mean
# 국가
# Brunei  21198560.2  451033.195745

# %% [markdown]
# #### 데이터프레임의 재구조화
# - pivot_table()
#     - 기존의 데이터프레임의 데이터들을 기준으로 새로운 데이터프레임을 생성
#     - 인덱스와 컬럼, 사용할 데이터을 데이터프레임에서 선택하여 구조를 새로 만든다.

# %%
pd.pivot_table(
    sales, 
    index = ['대륙', '국가'], 
    columns= '채널',
    values = '총이윤', 
    aggfunc= ['sum', 'mean']
)
# Out:
#                                        sum                        mean  \
# 채널                                 Offline       Online        Offline
# 대륙                 국가
# Asia               Bangladesh   9952040.14  18140680.63  355430.005000
#                    Bhutan      13144241.51  10689527.73  469437.196786
#                    Brunei       8761013.35  12437546.85  417191.111905
#                    Cambodia     9695262.62  14048900.27  387810.504800
#                    China       13468823.66  11239192.06  498845.320741
# ...                                    ...          ...            ...
# Sub-Saharan Africa The Gambia  11579401.05   6739474.10  526336.411364
#                    Togo        10918610.28   9107925.90  341206.571250
#                    Uganda      12002629.58  13938025.73  500109.565833
#                    Zambia      11247814.98  12389638.02  468658.957500
#                    Zimbabwe     7374924.93  13799706.83  335223.860455
#
#
# 채널                                    Online
# 대륙                 국가
# Asia               Bangladesh  518305.160857
#                    Bhutan      381768.847500
#                    Brunei      478367.186538
#                    Cambodia    342656.104146
#                    China       416266.372593
# ...                                      ...
# Sub-Saharan Africa The Gambia  306339.731818
#                    Togo        364317.036000
#                    Uganda      449613.733226
#                    Zambia      344156.611667
#                    Zimbabwe    372965.049459
#
# [185 rows x 4 columns]

# %%
# groupby()에서 그룹화된 데이터프레임을 출력 
group_data3 = sales[['대륙', '총이윤']].groupby('대륙')

# %%
group_data3.get_group('Asia')
# Out:
#         대륙        총이윤
# 0     Asia  236065.20
# 1     Asia  100322.99
# 2     Asia    2146.42
# 3     Asia  865347.12
# 4     Asia  976038.75
# ...    ...        ...
# 1464  Asia  980452.93
# 1465  Asia  463211.25
# 1466  Asia  330387.20
# 1467  Asia   39845.40
# 1468  Asia  872805.30
#
# [1469 rows x 2 columns]

# %%
group_data4 = sales[['국가', '총이윤']].groupby('국가').sum()

# %%
group_data4.sort_values('총이윤', ascending=False, inplace=True)

# %%
group_data4
# Out:
#                     총이윤
# 국가
# Kiribati    32454798.26
# Qatar       30861356.79
# Grenada     30302769.90
# Taiwan      30044779.98
# Malawi      29329125.05
# ...                 ...
# Cape Verde  14383303.52
# Italy       14199991.25
# Malta       14163744.55
# Mali        13800334.90
# Tajikistan  13662027.26
#
# [185 rows x 1 columns]

# %%
group_data4.iloc[2].name
# Out:
# 'Grenada'

# %%
# 반복문을 이용하여 South Korea의 위치 찾기 
# 국가는 index로 되어있다 
for i in range(0, len(group_data4), 1):
    # 만약에 group_data4.iloc[i]의 name이 South Korea 라면?
    if group_data4.iloc[i].name == 'South Korea':
        print(i)
        # break

print(i)
# Out:
# 47
# 184

# %%
i = 0

while True:
    try : 
        if group_data4.iloc[i].name == 'South Korea':
            print(i)
            break
        i += 1
    except:
        break
# Out:
# 47

# %%
# DataFrame에 index는 list형태
index_list = list(group_data4.index)

# %%
index_list.index('South Korea')
# Out:
# 47

# %%
group_data4.reset_index(inplace=True)

# %%
group_data4
# Out:
#              국가          총이윤
# 0      Kiribati  32454798.26
# 1         Qatar  30861356.79
# 2       Grenada  30302769.90
# 3        Taiwan  30044779.98
# 4        Malawi  29329125.05
# ..          ...          ...
# 180  Cape Verde  14383303.52
# 181       Italy  14199991.25
# 182       Malta  14163744.55
# 183        Mali  13800334.90
# 184  Tajikistan  13662027.26
#
# [185 rows x 2 columns]

# %%
group_data4.loc[
    group_data4['국가'] == 'South Korea'
]
# Out:
#              국가          총이윤
# 47  South Korea  23893933.75

# %%
group_data5 = sales[['국가', '총이윤']].groupby('국가').sum()

# %%
# 특정 컬럼을 기준으로 랭킹을 잡아주는 함수
# rank()
group_data5['rank'] = group_data5['총이윤'].rank(ascending=False)

# %%
group_data5.loc['South Korea']
# Out:
# 총이윤     23893933.75
# rank          48.00
# Name: South Korea, dtype: float64

# %%
group_data5
# Out:
#                       총이윤   rank
# 국가
# Afghanistan   22977020.06   67.0
# Albania       19583969.70  124.0
# Algeria       22125886.64   80.0
# Andorra       16653936.87  167.0
# Angola        19596150.58  123.0
# ...                   ...    ...
# Vatican City  16978429.04  160.0
# Vietnam       23415377.02   54.0
# Yemen         16666875.07  166.0
# Zambia        23637453.00   53.0
# Zimbabwe      21174631.76   94.0
#
# [185 rows x 2 columns]
