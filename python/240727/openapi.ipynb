# %%
# 라이브러리 설치 
# !pip install requests

# %% [markdown]
# #### requests 라이브러리
# 1. 특정한 웹 주소에 요청을 보내는 기능을 가진 라이브러리
# 2. 요청 후 응답 메시지를 저장

# %%
import requests

# %%
# local server에 있는 데이터 api에 요청
url = "http://127.0.0.1:5000/data"

# 서버에게 보낼 데이터를 dict형태로 생성
parameter = {
    'service_id' : 'test10', 
    'service_pass' : '1111'
}

# 서버에게 요청을 보낸다. (데이터를 실어서)
reponse = requests.get(url, params=parameter)

# %%
reponse
# Out:
# <Response [200]>

# %%
reponse.content
# Out:
# b'[\n  {\n    "beer_servings": 0,\n    "continent": "AS",\n    "country": "Afghanistan",\n    "spirit_servings": 0,\n    "total_litres_of_pure_alcohol": 0.0,\n    "wine_servings": 0\n  },\n  {\n    "beer_servings": 89,\n    "continent": "EU",\n    "country": "Albania",\n    "spirit_servings": 132,\n    "total_litres_of_pure_alcohol": 4.9,\n    "wine_servings": 54\n  },\n  {\n    "beer_servings": 25,\n    "continent": "AF",\n    "country": "Algeria",\n    "spirit_servings": 0,\n    "total_litres_of_pure_alcohol": 0.7,\n    "wine_servings": 14\n  },\n  {\n    "beer_servings": 245,\n    "continent": "EU",\n    "country": "Andorra",\n    "spirit_servings": 138,\n    "total_litres_of_pure_alcohol": 12.4,\n    "wine_servings": 312\n  },\n  {\n    "beer_servings": 217,\n    "continent": "AF",\n    "country": "Angola",\n    "spirit_servings": 57,\n    "total_litres_of_pure_alcohol": 5.9,\n    "wine_servings": 45\n  },\n  {\n    "beer_servings": 102,\n    "continent": "NA",\n    "country": "Antigua & Barbuda",\n    "spirit_servings": 128,\n    "total_litres_of_pure_alcohol": 4.9,\n    "wine_servings": 45\n  },\n  {\n    "beer_servings": 193,\n    "continent": "SA",\n    "country": "Argentina",\n    "spirit_servings": 25,\n    "total_litres_of_pure_alcohol": 8.3,\n    "wine_servings": 221\n  },\n  {\n    "beer_servings": 21,\n    "continent": "EU",\n    "country": "Armenia",\n    "spirit_servings": 179,\n    "total_litres_of_pure_alcohol": 3.8,\n    "wine_servings": 11\n  },\n  {\n    "beer_servings": 261,\n    "continent": "OC",\n    "country": "Australia",\n    "spirit_servings": 72,\n    "total_litres_of_pure_alcohol": 10.4,\n    "wine_servings": 212\n  },\n  {\n    "beer_servings": 279,\n    "continent": "EU",\n    "country": "Austria",\n    "spirit_servings": 75,\n    "total_litres_of_pure_alcohol": 9.7,\n    "wine_servings": 191\n  },\n  {\n    "beer_servings": 21,\n    "continent": "EU",\n    "country": "Azerbaijan",\n    "spirit_servings": 46,\n    "total_litres_of_pure_alcohol": 1.3,\n    "wine_servings": 5\n  },\n  {\n    "beer_servings": 122,\n    "continent": "NA",\n    "country": "Bahamas",\n    "spirit_servings": 176,\n    "total_litres_of_pure_alcohol": 6.3,\n    "wine_servings": 51\n  },\n  {\n    "beer_servings": 42,\n    "continent": "AS",\n    "country": "Bahrain",\n    "spirit_servings": 63,\n    "total_litres_of_pure_alcohol": 2.0,\n    "wine_servings": 7\n  },\n  {\n    "beer_servings": 0,\n    "continent": "AS",\n    "country": "Bangladesh",\n    "spirit_servings": 0,\n    "total_litres_of_pure_alcohol": 0.0,\n    "wine_servings": 0\n  },\n  {\n    "beer_servings": 143,\n    "continent": "NA",\n    "country": "Barbados",\n    "spirit_servings": 173,\n    "total_litres_of_pure_alcohol": 6.3,\n    "wine_servings": 36\n  },\n  {\n    "beer_servings": 142,\n    "continent": "EU",\n    "country": "Belarus",\n    "spirit_servings": 373,\n    "total_litres_of_pure_alcohol": 14.4,\n    "wine_servings": 42\n  },\n  {\n    "beer_servings": 295,\n    "continent": "EU",\n    "country": "Belgium",\n    "spirit_servings": 84,\n    "total_litres_of_pure_alcohol": 10.5,\n    "wine_servings": 212\n  },\n  {\n    "beer_servings": 263,\n    "continent": "NA",\n    "country": "Belize",\n    "spirit_servings": 114,\n    "total_litres_of_pure_alcohol": 6.8,\n    "wine_servings": 8\n  },\n  {\n    "beer_servings": 34,\n    "continent": "AF",\n    "country": "Benin",\n    "spirit_servings": 4,\n    "total_litres_of_pure_alcohol": 1.1,\n    "wine_servings": 13\n  },\n  {\n    "beer_servings": 23,\n    "continent": "AS",\n    "country": "Bhutan",\n    "spirit_servings": 0,\n    "total_litres_of_pure_alcohol": 0.4,\n    "wine_servings": 0\n  },\n  {\n    "beer_servings": 167,\n    "continent": "SA",\n    "country": "Bolivia",\n    "spirit_servings": 41,\n    "total_litres_of_pure_alcohol": 3.8,\n    "wine_servings": 8\n  },\n  {\n    "beer_servings": 76,\n    "continent": "EU",\n    "country": "Bosnia-Herzegovina",\n    "spirit_servings": 1 ...

# %%
# local server에 있는 데이터 api에 요청
url = "http://127.0.0.1:5000/data"

# 서버에게 보낼 데이터를 dict형태로 생성
parameter = {
    'service_id' : 'test10', 
    'service_pass' : '1111', 
    'continent' : 'EU'
}

# 서버에게 요청을 보낸다. (데이터를 실어서)
reponse = requests.get(url, params=parameter)

# %%
reponse.content
# Out:
# b'[\n  {\n    "beer_servings": 89,\n    "continent": "EU",\n    "country": "Albania",\n    "spirit_servings": 132,\n    "total_litres_of_pure_alcohol": 4.9,\n    "wine_servings": 54\n  },\n  {\n    "beer_servings": 245,\n    "continent": "EU",\n    "country": "Andorra",\n    "spirit_servings": 138,\n    "total_litres_of_pure_alcohol": 12.4,\n    "wine_servings": 312\n  },\n  {\n    "beer_servings": 21,\n    "continent": "EU",\n    "country": "Armenia",\n    "spirit_servings": 179,\n    "total_litres_of_pure_alcohol": 3.8,\n    "wine_servings": 11\n  },\n  {\n    "beer_servings": 279,\n    "continent": "EU",\n    "country": "Austria",\n    "spirit_servings": 75,\n    "total_litres_of_pure_alcohol": 9.7,\n    "wine_servings": 191\n  },\n  {\n    "beer_servings": 21,\n    "continent": "EU",\n    "country": "Azerbaijan",\n    "spirit_servings": 46,\n    "total_litres_of_pure_alcohol": 1.3,\n    "wine_servings": 5\n  },\n  {\n    "beer_servings": 142,\n    "continent": "EU",\n    "country": "Belarus",\n    "spirit_servings": 373,\n    "total_litres_of_pure_alcohol": 14.4,\n    "wine_servings": 42\n  },\n  {\n    "beer_servings": 295,\n    "continent": "EU",\n    "country": "Belgium",\n    "spirit_servings": 84,\n    "total_litres_of_pure_alcohol": 10.5,\n    "wine_servings": 212\n  },\n  {\n    "beer_servings": 76,\n    "continent": "EU",\n    "country": "Bosnia-Herzegovina",\n    "spirit_servings": 173,\n    "total_litres_of_pure_alcohol": 4.6,\n    "wine_servings": 8\n  },\n  {\n    "beer_servings": 231,\n    "continent": "EU",\n    "country": "Bulgaria",\n    "spirit_servings": 252,\n    "total_litres_of_pure_alcohol": 10.3,\n    "wine_servings": 94\n  },\n  {\n    "beer_servings": 230,\n    "continent": "EU",\n    "country": "Croatia",\n    "spirit_servings": 87,\n    "total_litres_of_pure_alcohol": 10.2,\n    "wine_servings": 254\n  },\n  {\n    "beer_servings": 192,\n    "continent": "EU",\n    "country": "Cyprus",\n    "spirit_servings": 154,\n    "total_litres_of_pure_alcohol": 8.2,\n    "wine_servings": 113\n  },\n  {\n    "beer_servings": 361,\n    "continent": "EU",\n    "country": "Czech Republic",\n    "spirit_servings": 170,\n    "total_litres_of_pure_alcohol": 11.8,\n    "wine_servings": 134\n  },\n  {\n    "beer_servings": 224,\n    "continent": "EU",\n    "country": "Denmark",\n    "spirit_servings": 81,\n    "total_litres_of_pure_alcohol": 10.4,\n    "wine_servings": 278\n  },\n  {\n    "beer_servings": 224,\n    "continent": "EU",\n    "country": "Estonia",\n    "spirit_servings": 194,\n    "total_litres_of_pure_alcohol": 9.5,\n    "wine_servings": 59\n  },\n  {\n    "beer_servings": 263,\n    "continent": "EU",\n    "country": "Finland",\n    "spirit_servings": 133,\n    "total_litres_of_pure_alcohol": 10.0,\n    "wine_servings": 97\n  },\n  {\n    "beer_servings": 127,\n    "continent": "EU",\n    "country": "France",\n    "spirit_servings": 151,\n    "total_litres_of_pure_alcohol": 11.8,\n    "wine_servings": 370\n  },\n  {\n    "beer_servings": 52,\n    "continent": "EU",\n    "country": "Georgia",\n    "spirit_servings": 100,\n    "total_litres_of_pure_alcohol": 5.4,\n    "wine_servings": 149\n  },\n  {\n    "beer_servings": 346,\n    "continent": "EU",\n    "country": "Germany",\n    "spirit_servings": 117,\n    "total_litres_of_pure_alcohol": 11.3,\n    "wine_servings": 175\n  },\n  {\n    "beer_servings": 133,\n    "continent": "EU",\n    "country": "Greece",\n    "spirit_servings": 112,\n    "total_litres_of_pure_alcohol": 8.3,\n    "wine_servings": 218\n  },\n  {\n    "beer_servings": 234,\n    "continent": "EU",\n    "country": "Hungary",\n    "spirit_servings": 215,\n    "total_litres_of_pure_alcohol": 11.3,\n    "wine_servings": 185\n  },\n  {\n    "beer_servings": 233,\n    "continent": "EU",\n    "country": "Iceland",\n    "spirit_servings": 61,\n    "total_litres_of_pure_alcohol": 6.6,\n    "wine_servings": 78\n  },\n  {\n    "beer_servings": 313,\n    "continent": "EU",\n    "country": "Ireland", ...

# %%
import json
import pandas as pd

# %%
pd.DataFrame(json.loads(reponse.content))
# Out:
#     beer_servings continent             country  spirit_servings  \
# 0              89        EU             Albania              132
# 1             245        EU             Andorra              138
# 2              21        EU             Armenia              179
# 3             279        EU             Austria               75
# 4              21        EU          Azerbaijan               46
# 5             142        EU             Belarus              373
# 6             295        EU             Belgium               84
# 7              76        EU  Bosnia-Herzegovina              173
# 8             231        EU            Bulgaria              252
# 9             230        EU             Croatia               87
# 10            192        EU              Cyprus              154
# 11            361        EU      Czech Republic              170
# 12            224        EU             Denmark               81
# 13            224        EU             Estonia              194
# 14            263        EU             Finland              133
# 15            127        EU              France              151
# 16             52        EU             Georgia              100
# 17            346        EU             Germany              117
# 18            133        EU              Greece              112
# 19            234        EU             Hungary              215
# 20            233        EU             Iceland               61
# 21            313        EU             Ireland              118
# 22             85        EU               Italy               42
# 23            281        EU              Latvia              216
# 24            343        EU           Lithuania              244
# 25            236        EU          Luxembourg              133
# 26            149        EU               Malta              100
# 27              0        EU              Monaco                0
# 28             31        EU          Montenegro              114
# 29            251        EU         Netherlands               88
# 30            169        EU              Norway               71
# 31            343        EU              Poland              215
# 32            194        EU            Portugal               67
# 33            109        EU             Moldova              226
# 34            297        EU             Romania              122
# 35              0        EU          San Marino                0
# 36            283        EU              Serbia              131
# 37            196        EU            Slovakia              293
# 38            270        EU            Slovenia               51
# 39            284        EU               Spain              157
# 40            152        EU              Sweden               60
# 41            185        EU         Switzerland              100
# 42            106        EU           Macedonia               27
# 43            206        EU             Ukraine              237
# 44            219        EU      United Kingdom              126
#
#     total_litres_of_pure_alcohol  wine_servings
# 0                            4.9             54
# 1                           12.4            312
# 2                            3.8             11
# 3                            9.7            191
# 4                            1.3              5
# 5                           14.4             42
# 6                           10.5            212
# 7                            4.6              8
# 8                           10.3             94
# 9                           10.2            254
# 10                           8.2            113
# 11                          11.8            134
# 12                          10.4            278
# 13                           9.5             59
# 14                          10.0             97
# 15                          11.8            370
# 16                           5.4            149
# 17                          11.3            175
# 18                           8.3            218
# 19                          11.3            185
# 20                           6.6             78
# 21                          11.4            165
# 22                           6.5            237
# 23                          10.5             62
# 24                          12.9             56
# 25                          11.4            271
# 26                           6.6            120
# 27                           0.0              0
# 28                           4.9            128
# 29                           9.4            190
# 30                           6.7            129
# 31                          10.9             56
# 32                          11.0            339
# 33                           6.3             18
# 34                          10.4            167
# 35                           0.0              0
# 36                           9.6            127
# 37                          11.4            116
# 38                          10.6            276
# 39                          10.0            112
# 40                           7.2            186
# 41                          10.2            280
# 42                           3.9             86
# 43                           8.9             45
# 44                          10.4            195

# %%
# !pip install xmltodict

# %%
# 공공데이터포털 부동산 매매 신고 자료 api
import requests 
import json
import pandas as pd
import xmltodict

# %%
# 서버의 주소 
url =  'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade'

service_key = 'dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw=='
